# %% [markdown]
# following notebook of [Charles Chu](https://www.kaggle.com/chuhimself/d/wendykan/lending-club-loan-data/exploratory-analysis)
#
# How much are the loans for?
# How long are the loans taken for?
# What is the interest rate?
# About the peopl:
# What kind of people take out loans?
# Where are they from?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('loan.csv', low_memory=False)

# %%
df['addr_state'].value_counts().plot(kind='bar')

# %%
df['annual_inc'].plot.density()

# %%
df['funded_amnt'].hist()
plt.title('Funded Amount')
